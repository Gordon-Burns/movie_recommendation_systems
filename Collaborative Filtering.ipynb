# %% [markdown]
# # Collaborative-Based Filtering

# %% [markdown]
# ### Load the data

# %%
import  pandas
ratings = pandas.read_csv("ratings.csv")[["userId","movieId","rating"]]

# %% [markdown]
# ## Create the dataset

# %%
from surprise import Dataset , Reader
reader = Reader(rating_scale=(1,5))
dataset = Dataset.load_from_df(ratings,reader)

# %% [markdown]
# ### Build the trainset

# %%
trainset = dataset.build_full_trainset()

# %% [markdown]
# ## Train the model

# %%
from surprise import SVD
svd = SVD()

# %%
svd.fit(trainset)

# %%
svd.predict(15,1956)
# Out:
# Prediction(uid=15, iid=1956, r_ui=None, est=3.2884382322889962, details={'was_impossible': False})

# %% [markdown]
# ## Validation

# %%
from surprise import model_selection

model_selection.cross_validate(svd,dataset,measures=['RMSE',"MAE"])
# Out:
# {'test_rmse': array([0.89402454, 0.89787632, 0.89740422, 0.89353905, 0.9022757 ]),
#  'test_mae': array([0.69052332, 0.69093873, 0.69318379, 0.68825535, 0.69389786]),
#  'fit_time': (1.033982515335083,
#   1.072969675064087,
#   1.0989089012145996,
#   0.9970173835754395,
#   1.020385503768921),
#  'test_time': (0.19249796867370605,
#   0.1889052391052246,
#   0.20800018310546875,
#   0.1384751796722412,
#   0.4035036563873291)}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d1ff9ce0-37ab-460f-bbf9-10ffc0ecbd67' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
